# %% [markdown]
# # List Methods

# %%
#list
list1 = ['ai','dS','CS',150,20,True,[3,4],(1,2)]

# %%
list1
# Out:
# ['ai', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list1[0]
# Out:
# 'ai'

# %%
list1[-1]
# Out:
# (1, 2)

# %%
list1[-1][0]
# Out:
# 1

# %%
list1[-1][-2]
# Out:
# 1

# %% [markdown]
# # Copy()

# %%
list2 = list1

# %%
list2
# Out:
# ['ai', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list1
# Out:
# ['ai', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list3 = list1.copy()

# %%
list3
# Out:
# ['ai', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list1[0] = '1000'

# %%
list1
# Out:
# ['1000', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list2
# Out:
# ['1000', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list3[0] = 'data'

# %%
list3
# Out:
# ['data', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %%
list1
# Out:
# ['1000', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2)]

# %% [markdown]
# # Append()

# %%
list1.append(28)

# %%
list1
# Out:
# ['1000', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2), 28]

# %%
l1 = [10,100.30]

# %%
l1
# Out:
# [10, 100.3]

# %%
list1.append(l1)

# %%
list1
# Out:
# ['1000', 'dS', 'CS', 150, 20, True, [3, 4], (1, 2), 28, [10, 100.3]]

# %%
list1[-1]
# Out:
# [10, 100.3]

# %%
list1.append({1,2,3,4})

# %%
list1
# Out:
# ['1000',
#  'dS',
#  'CS',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100.3],
#  {1, 2, 3, 4}]

# %%
list1[-1]
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # Extend()

# %%
list1.extend(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed784c86b4c9> in <module>()
# ----> 1 list1.extend(l1)
#
# NameError: name 'list1' is not defined

# %%
list1

# %%
list1[-2]

# %% [markdown]
# # Insert()

# %%
list1.insert(0,'FAU')

# %%
list1

# %%
list1[0] = 'Germany'

# %%
list1

# %% [markdown]
# # index()

# %%
list1.index(150)
# Out:
# 4

# %%
list1.index({1, 2, 3, 4})
# Out:
# 11

# %% [markdown]
# # Count()

# %%
list1.count({1, 2, 3, 4})
# Out:
# 1

# %%
list1.count(150)
# Out:
# 1

# %% [markdown]
# # sort()

# %%
ls2 = [10,2,6,7,9,100]

# %%
ls2.sort()

# %%
ls2
# Out:
# [2, 6, 7, 9, 10, 100]

# %% [markdown]
# # reverse()

# %%
ls2.reverse()

# %%
ls2
# Out:
# [100, 10, 9, 7, 6, 2]

# %% [markdown]
# # remove()

# %%
ls2.remove(100)

# %%
ls2
# Out:
# [10, 9, 7, 6, 2]

# %% [markdown]
# # Pop()

# %%
ls2.pop(-1)
# Out:
# 2

# %%
ls2
# Out:
# [10, 9, 7, 6]

# %%
del ls2[0] # delete

# %%
ls2
# Out:
# [9, 7, 6]

# %%
ls2
# Out:
# [9, 7, 6]

# %%
ls2.clear()

# %%
ls2
# Out:
# []

# %%
type(ls2)
# Out:
# list
